# %%
import requests
import re

# %%
url = "https://iranopasmigirim.com/fa"

headers = {
    "Content-Type": "text/plain;charset=UTF-8",
    "Accept": "text/x-component",
    "Origin": "https://iranopasmigirim.com",
    "Referer": "https://iranopasmigirim.com/fa",
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/140 Safari/537.36",
    # Replace this with the action id you see for getMunichSignatureCount
    "next-action": "00e11c6c29256f5f1aefbfe3182a1608edc820807c",
}

# If DevTools showed a request body, paste it here. Otherwise, maybe just "[]"
body = "[]"

resp = requests.post(url, headers=headers, data=body.encode("utf-8"))
print("HTTP", resp.status_code)
m = re.search(r'"count":\s*(\d+)', resp.text)
if m:
    print("Signature count:", m.group(1))
else:
    print("not found")
# Out:
# HTTP 200
# Signature count: 317759

# %%
# Out:
# Signature count: 315904

# %%
resp.text
# Out:
# '2:"$Sreact.fragment"\n3:I[87555,[],""]\n4:I[31295,[],""]\n5:I[34584,["6874","static/chunks/6874-6eed7c54e5579ddc.js?dpl=dpl_Hh4tYAej7Vrq8YanMCGuBxAWPnJ3","4345","static/chunks/app/not-found-4ae266615d5867d1.js?dpl=dpl_Hh4tYAej7Vrq8YanMCGuBxAWPnJ3"],"default"]\n8:I[59665,[],"OutletBoundary"]\nb:I[74911,[],"AsyncMetadataOutlet"]\nd:I[59665,[],"ViewportBoundary"]\nf:I[59665,[],"MetadataBoundary"]\n11:"$Sreact.suspense"\n12:I[74911,[],"AsyncMetadata"]\n14:I[50022,["6874","static/chunks/6874-6eed7c54e5579ddc.js?dpl=dpl_Hh4tYAej7Vrq8YanMCGuBxAWPnJ3","3063","static/chunks/3063-c556ec2ffc24299b.js?dpl=dpl_Hh4tYAej7Vrq8YanMCGuBxAWPnJ3","6386","static/chunks/6386-c46222c5cccb7a15.js?dpl=dpl_Hh4tYAej7Vrq8YanMCGuBxAWPnJ3","8925","static/chunks/8925-45b2244dc45a7b36.js?dpl=dpl_Hh4tYAej7Vrq8YanMCGuBxAWPnJ3","6794","static/chunks/6794-9cb87b639499f369.js?dpl=dpl_Hh4tYAej7Vrq8YanMCGuBxAWPnJ3","9862","static/chunks/9862-148f52ebcebdde5a.js?dpl=dpl_Hh4tYAej7Vrq8YanMCGuBxAWPnJ3","3545","static/chunks/
# ...
